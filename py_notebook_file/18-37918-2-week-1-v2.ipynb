# %% [markdown]
# # Name: Md. Jamil Istiaq, Id: 18-37918-2, Sec:F, week-1 v2

# %% [markdown]
# Number example

# %%
a= 23
b=4.3
c=5
a+b
# Out:
# 27.3

# %%
a-b
# Out:
# 18.7

# %%
a*b
# Out:
# 98.89999999999999

# %%
a/b-c
# Out:
# 0.3488372093023262

# %%
a+b+c
# Out:
# 32.3

# %% [markdown]
# import math
# math.pi
# math.sqrt(a)

# %% [markdown]
# sqrt of the sum of a and b

# %%
math.sqrt(a+b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-52be286f87a4> in <module>
# ----> 1 math.sqrt(a+b)
#
# NameError: name 'math' is not defined

# %%
import random

# %%
random.random()

# %%
random.choice([1,3,5])

# %%
a**2

# %% [markdown]
# mod of b

# %% [markdown]
# math.modf(b)

# %% [markdown]
# sin value for the sum a and b

# %%
math.sin(a+b)

# %% [markdown]
# sting examples

# %%
st= 'IEEE AIUB Student Branch'

# %%
st
# Out:
# 'IEEE AIUB Student Branch'

# %% [markdown]
# length of the string

# %%
len(st)
# Out:
# 24

# %% [markdown]
# last letter

# %%
st[-1]

# %%
st[1:-3]

# %%
st[-6:]

# %% [markdown]
# concate new word

# %%
st + ' R10'

# %% [markdown]
# find a word in the string

# %%
st.find('dent')

# %% [markdown]
# replace a word

# %%
st.replace('IEEE','ieee')
# Out:
# 'ieee AIUB Student Branch'

# %% [markdown]
# Immutability

# %%
st='J'+st[1:]

# %%
st
# Out:
# 'JEEE AIUB Student Branch'

# %%
st.split(' ')
# Out:
# ['JEEE', 'AIUB', 'Student', 'Branch']

# %%
st.upper()

# %%
st.lower()

# %% [markdown]
# how many string are there

# %%
st.count(st)

# %%
st.isalpha()
# Out:
# False

# %% [markdown]
# list example

# %%
list=[1,2.3, 'jamil', 'ai', 'cs', 'ieeer10']
len(list)

# %%
list[0]

# %%
list[2]

# %% [markdown]
# add new iteam in list

# %%
list+['aiub', 'cse']

# %%
len(list)

# %%
list.append('aiub')

# %%
len(list)

# %%
list

# %% [markdown]
# delete last one

# %%
del list[-1]

# %%
list

# %% [markdown]
# matrix

# %%
mat=[[1,2,3],['a','b','c'],[4,5,7]]

# %%
mat

# %%
mat[1]

# %%
mat[1][2]

# %% [markdown]
# dictionary

# %%
dis={'name':'jamil', 'id':'18-37918-2','dept':'CSE'}

# %%
dis
# Out:
# {'name': 'jamil', 'id': '18-37918-2', 'dept': 'CSE'}

# %%
dis['name']
# Out:
# 'jamil'

# %%
dis={'a':'10','x':'12','y':'14','z':'15'}

# %% [markdown]
# print keys

# %%
d=dis.keys()
d
# Out:
# dict_keys(['a', 'x', 'y', 'z'])

# %%
for key in d:
    print(key,'=>',dis[key])
# Out:
# a => 10
# x => 12
# y => 14
# z => 15

# %%
for key in sorted(d):
    print(key,'=>',dis[key])
# Out:
# a => 10
# x => 12
# y => 14
# z => 15

# %% [markdown]
# squre all value in a list

# %%
sq=[x**2 for x in [2,4,6]]
sq

# %% [markdown]
# touple

# %%
t=(2,3,5,7,8,9)
len(t)

# %% [markdown]
# Function Home Work

# %% [markdown]
# define a function cal_add(), it take two parameter for sum, we gave two value and return the sum. finaly printout the result.

# %%
def cal_add(x,y):
    sum=x+y
    return sum
a=3
b=7

print('The Sum is',cal_add(a,b))
# Out:
# The Sum is 10

# %% [markdown]
# file

# %%
f=open('ai.txt','w')

# %%
f.write('Hello, This is the first lab\n')

# %%
f.write('Name: Md. Jamil Istiaq\n')

# %%
f.close()

# %%
f=open('ai.txt')
bytes=f.read()
bytes

# %%
print(bytes)

# %%
bytes.split()

# %%
bytes.upper()
